# %%
from pathlib import Path

# %%
import shutil

# %%
path = Path("test_cases")

# %%
path.is_dir()
# Out:
# True

# %%
path.is_file()
# Out:
# False

# %%
for item in path.iterdir() :
    print(item)
    patharr = str(item).split("/") 
    print(patharr[1])
    filename = patharr[1]
    filenamearr = str(filename).split("_")
    source = Path(item)
    destination_path = patharr[0] + "/" + filenamearr[0] + "/" +filename
    print(destination_path)
    destination = Path(destination_path)
    
    destination.parent.mkdir(parents=True , exist_ok=True )
    #shutil.move(source , destination)
# Out:
# test_cases/login
# login
# test_cases/login/login

# %%
s
