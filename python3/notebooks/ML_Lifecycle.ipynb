# %% [markdown]
# Refer [ML Lifecycle](https://github.com/WillKoehrsen/machine-learning-project-walkthrough/blob/master/Machine%20Learning%20Project%20Part%203.ipynb)

# %% [markdown]
# ## Data Loading

# %% [markdown]
# ### 1.1 Data Cleaning

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('T1.csv')

# %%
data
# Out:
#               Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0      01 01 2018 00:00           380.047791          5.311336
# 1      01 01 2018 00:10           453.769196          5.672167
# 2      01 01 2018 00:20           306.376587          5.216037
# 3      01 01 2018 00:30           419.645905          5.659674
# 4      01 01 2018 00:40           380.650696          5.577941
# ...                 ...                  ...               ...
# 50525  31 12 2018 23:10          2963.980957         11.404030
# 50526  31 12 2018 23:20          1684.353027          7.332648
# 50527  31 12 2018 23:30          2201.106934          8.435358
# 50528  31 12 2018 23:40          2515.694092          9.421366
# 50529  31 12 2018 23:50          2820.466064          9.979332
#
#        Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                         416.328908          259.994904
# 1                         519.917511          268.641113
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50530 entries, 0 to 50529
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date/Time                      50530 non-null  object
#  1   LV ActivePower (kW)            50530 non-null  float64
#  2   Wind Speed (m/s)               50530 non-null  float64
#  3   Theoretical_Power_Curve (KWh)  50530 non-null  float64
#  4   Wind Direction (°)             50530 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# ### 1.2 Convert to correct types

# %% [markdown]
# ### 1.3 Remove columns with missing values

# %% [markdown]
# ## 2 Exploratory Data Analysis

# %%
plt.hist(data['Wind Speed (m/s)'])
# Out:
# (array([ 5679., 10204., 11582.,  9720.,  7045.,  3632.,  1541.,   885.,
#           202.,    40.]),
#  array([ 0.        ,  2.52060108,  5.04120216,  7.56180325, 10.08240433,
#         12.60300541, 15.12360649, 17.64420757, 20.16480865, 22.68540974,
#         25.20601082]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 2.2 Removing Outliers

# %% [markdown]
# ### 2.3 Looking for Relationships
