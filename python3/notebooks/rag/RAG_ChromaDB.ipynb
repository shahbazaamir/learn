# %% [markdown]
# ### install
# ```shell
# uv pip install chromadb
# ```

# %%
import chromadb

client = chromadb.CloudClient(
  api_key='ck-8m2ChQAUJiXRHBYp6ynux9E7yr911siwrt8HxbUWpBtc',
  tenant='11e46a87-1407-420a-a8e0-7bcfcb27fe9f',
  database='gpdb'
)
